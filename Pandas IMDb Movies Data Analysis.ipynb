# %% [markdown]
# # Pandas IMDb Movies Data Analysis

# %% [markdown]
# In this practice exercise i used database movies_metadata.csv

# %% [markdown]
# https://www.w3resource.com/python-exercises/pandas/movies/index.php?passed=passed

# %% [markdown]
# # 1. Write a Python Pandas program to get the columns of the DataFrame (movies_metadata.csv file).

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
print("columns of dataframes are ")
print(df.columns)
# Out:
# columns of dataframes are
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# # 2. Write a Pandas program to get the information of the DataFrame (movies_metadata.csv file)including data types and memory usage.

# %%
print("information ",df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 24 columns):
# adult                    50 non-null bool
# belongs_to_collection    10 non-null object
# budget                   50 non-null int64
# genres                   50 non-null object
# homepage                 5 non-null object
# id                       50 non-null int64
# imdb_id                  50 non-null object
# original_language        50 non-null object
# original_title           50 non-null object
# overview                 49 non-null object
# popularity               50 non-null object
# poster_path              50 non-null object
# production_companies     50 non-null object
# production_countries     50 non-null object
# release_date             50 non-null object
# revenue                  50 non-null object
# runtime                  50 non-null int64
# spoken_languages         50 non-null object
# status                   50 non-null object
# ...

# %% [markdown]
# # 3. Write a Pandas program to get the details of the third movie of the DataFrame (movies_metadata.csv file).

# %%
print("Details of third movie\n ",df.iloc[2])
# Out:
# Details of third movie
#   adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# ...

# %% [markdown]
# # 4. Write a Pandas program to count the number of rows and columns of the DataFrame (movies_metadata.csv file

# %%
print("the number of rows and columns in dataframe are ",df.shape)
# Out:
# the number of rows and columns in dataframe are  (50, 24)

# %% [markdown]
# # 5. Write a Pandas program to get the details of the columns title and genres of the DataFrame

# %%
print("Details of colums")
details=df[['title','genres']]
details.head()
# Out:
# Details of colums
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]

# %% [markdown]
# # 6. Write a Pandas program to get the details of the movie with title 'Grumpier Old Men'.

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
df=df.set_index('title')
mv_details= df.loc['Grumpier Old Men']
print(mv_details)
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# ...

# %% [markdown]
# # 7. Write a Pandas program to get the details of  fifth movie of the DataFrame.

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
print("Details of fifth movie\n ",df.iloc[4])
# Out:
# Details of fifth movie
#   adult                                                                False
# belongs_to_collection    {'id': 96871, 'name': 'Father of the Bride Col...
# budget                                                                   0
# genres                                      [{'id': 35, 'name': 'Comedy'}]
# homepage                                                               NaN
# id                                                                   11862
# imdb_id                                                          tt0113041
# original_language                                                       en
# original_title                                 Father of the Bride Part II
# overview                 Just when George Banks has recovered from his ...
# popularity                                                        8.387519
# poster_path                               /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...

# %% [markdown]
# # 8. Write a Pandas program to create a smaller DataFrame with a subset of all features.

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
small_dataframe=df[['adult','belongs_to_collection','budget']]
print("Smaller dataframe\n",small_dataframe.head())
# Out:
# Smaller dataframe
#     adult                              belongs_to_collection    budget
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0

# %% [markdown]
# # 9. Write a Pandas program to display the first 10 rows of the DataFrame.

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
df.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %% [markdown]
# # 10. Write a Pandas program to sort the DataFrame based on release_date.

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
sort_result=df.sort_values('release_date')# asending order
print("Movies data sorted by release date\n",sort_result.head())
# Out:
# Movies data sorted by release date
#      adult belongs_to_collection    budget  \
# 48  False                   NaN         0
# 45  False                   NaN  10000000
# 22  False                   NaN  50000000
# 41  False                   NaN  10000000
# 34  False                   NaN         0
#
#                                                genres homepage     id  \
# 48  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   8391
# 45  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  11861
# 22  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN   9691
# 41  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN  11443
# 34  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...      NaN  47018
#
#       imdb_id original_language                 original_title  \
# 48  tt0114916                en          When Night Is Falling
# 45  tt0113347                en  How To Make An American Quilt
# ...

# %% [markdown]
# # 11. Write a Pandas program to access those movies, released after 1995-01-01

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
movies_after_date=df[df['release_date']>'1995-01-01']
print("Movies after 1995-01-01 are \n",movies_after_date.head())
# Out:
# Movies after 1995-01-01 are
#     adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 7  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# # 12. Write a Pandas program to sort movies on runtime in descending order.

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
sort_result=df.sort_values('runtime',ascending=False)
print("Movies data sorted by release date\n",sort_result.head())
# Out:
# Movies data sorted by release date
#      adult belongs_to_collection    budget  \
# 13  False                   NaN  44000000
# 15  False                   NaN  52000000
# 5   False                   NaN  60000000
# 16  False                   NaN  16500000
# 22  False                   NaN  50000000
#
#                                                genres homepage     id  \
# 13  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...      NaN  10858
# 15  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      NaN    524
# 5   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN    949
# 16  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   4584
# 22  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN   9691
#
#       imdb_id original_language         original_title  \
# 13  tt0113987                en                  Nixon
# 15  tt0112641                en                 Casino
# 5   tt0113277                en                   Heat
# ...

# %% [markdown]
# # 13. Write a Pandas program to get those movies whose revenue more than 2 million and spent less than 1 million.

# %%
df['revenue'].head()
# Out:
# 0    373554033
# 1    262797249
# 2            0
# 3     81452156
# 4     76578911
# Name: revenue, dtype: object

# %%
df['budget'].head()
# Out:
# 0    30000000
# 1    65000000
# 2           0
# 3    16000000
# 4           0
# Name: budget, dtype: int64

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
small_dataframe=df[['adult','belongs_to_collection','budget','revenue']]
result=small_dataframe[(small_dataframe['revenue']>'2000000') & (small_dataframe['budget']< 1000000)]
result
# Out:
#     adult                              belongs_to_collection  budget  \
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...       0
# 29  False                                                NaN       0
# 39  False                                                NaN       0
#
#        revenue
# 4     76578911
# 29  30-04-1995
# 39      676525

# %% [markdown]
# # 14. Write a Pandas program to get the longest runtime and shortest runtime.

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
small_dataframe=df[['adult','title','runtime']]
print("longest runtime \n",small_dataframe['runtime'].max())
print("shortest runtime \n",small_dataframe['runtime'].min())
# Out:
# longest runtime
#  192
# shortest runtime
#  0

# %% [markdown]
# # 15. Write a Pandas program to calculate the number of votes garnered by the 70% movie.

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
result = df['vote_count'].quantile(0.70)
print(result)
# Out:
# 402.6999999999999

# %% [markdown]
# # 16. Write a Pandas program to display the movies (title, runtime) longer than 30 minutes and shorter than 360 minutes.

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
small_df=df[['adult','title','runtime']]
result=small_df[(small_df['runtime']>30) & (small_df['runtime']<360) ]
result.head()
# Out:
#    adult                        title  runtime
# 0  False                    Toy Story       81
# 1  False                      Jumanji      104
# 2  False             Grumpier Old Men      101
# 3  False            Waiting to Exhale      127
# 4  False  Father of the Bride Part II      106

# %% [markdown]
# # 17. Write a Pandas program to display the movies (title, number of votes) that received specified number of votes

# %%
df['vote_count'].head(10)
# Out:
# 0    5415.0
# 1    2413.0
# 2      92.0
# 3      34.0
# 4     173.0
# 5    1886.0
# 6     141.0
# 7      45.0
# 8     174.0
# 9    1194.0
# Name: vote_count, dtype: float64

# %%
import pandas as pd
df=pd.read_csv('C:/Users/lenovo/Desktop/datasets/pandas_ex2/movies_metadata.csv',encoding='latin-1')
small_df=df[['title','vote_count']]
result=small_df[small_df['vote_count']>=500]
print("Movies title having votes greater than 500\n",result.head(10))
# Out:
# Movies title having votes greater than 500
#                               title  vote_count
# 0                        Toy Story      5415.0
# 1                          Jumanji      2413.0
# 5                             Heat      1886.0
# 9                        GoldenEye      1194.0
# 15                          Casino      1343.0
# 17                      Four Rooms       539.0
# 18  Ace Ventura: When Nature Calls      1128.0
# 31                  Twelve Monkeys      2470.0
# 33                            Babe       756.0
# 38                        Clueless       828.0
